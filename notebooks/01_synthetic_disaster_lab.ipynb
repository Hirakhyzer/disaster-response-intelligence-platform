# %% [markdown]
# # Synthetic Climate and Disaster Response Intelligence Lab
#
# This notebook runs fictional synthetic scenarios only. It does not provide official weather, satellite, evacuation, dispatch, or route guidance.

# %%
from pathlib import Path
import subprocess, sys, json
root = Path('..').resolve()
subprocess.run([sys.executable, 'scripts/run_synthetic_disaster_lab.py'], cwd=root, check=True)
summary = json.loads((root / 'outputs' / 'results' / 'synthetic_disaster_summary.json').read_text())
summary

# %% [markdown]
# ## Review outputs
# Open the generated maps and briefing under `outputs/figures/` and `outputs/reports/`. Keep the synthetic boundary clear in any discussion.

# %%
import pandas as pd
alerts = pd.read_csv(root / 'outputs' / 'results' / 'synthetic_alerts.csv')
assignments = pd.read_csv(root / 'outputs' / 'results' / 'synthetic_resource_assignments.csv')
alerts.head(), assignments.head()
